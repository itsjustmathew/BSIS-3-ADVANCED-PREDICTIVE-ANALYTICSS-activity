# %% [markdown]
# <a href="https://colab.research.google.com/github/itsjustmathew/BSIS-3-ADVANCED-PREDICTIVE-ANALYTICSS-activity/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import pandas as pd

# %%
df=pd.read_csv ("https://raw.githubusercontent.com/itsjustmathew/BSIS-3-ADVANCED-PREDICTIVE-ANALYTICSS/main/dataset")

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
Data = df [['UnitPrice','Quantity']].values

# %%
plt.scatter(Data[:, 0], Data[:, 1], s=50, cmap='viridis')
plt.title("Original Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()
# Out:
# <ipython-input-27-488c59aac487>:1: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(Data[:, 0], Data[:, 1], s=50, cmap='viridis')

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
predicted_labels = kmeans.fit_predict(Data)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
df = df.set_index('UnitPrice','Quantity')
df.index = pd.to_datetime(df.index)
# Out:
# <ipython-input-30-12e0c5cc8dad>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.set_index except for the argument 'keys' will be keyword-only.
#   df = df.set_index('UnitPrice','Quantity')

# %%
def create_features(df):
    df = df.copy()
    df['hour'] = df.index.hour
    df['dayofweek'] = df.index.day_of_week
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['dayofyear'] = df.index.dayofyear
    return df

df = create_features(df)

# %%
plt.scatter(Data[:, 0], Data[:, 1], c=predicted_labels, s=50, cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')
plt.title("Initial Clustering Result")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.show()

# %%
for iteration in range(2):  # Repeat for a few iterations (you can adjust this number)
    # Step 3: Reassign Data Points
    predicted_labels = kmeans.predict(Data)

    # Step 4: Update Centroids
    kmeans.cluster_centers_ = np.array([Data[predicted_labels == i].mean(axis=0) for i in range(kmeans.n_clusters)])

    # Visualization
    plt.scatter(Data[:, 0], Data[:, 1], c=predicted_labels, s=50, cmap='viridis')
    plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')
    plt.title(f"Iteration {iteration + 1}")
    plt.xlabel("Feature 1")
    plt.ylabel("Feature 2")
    plt.legend()
    plt.show()
